# %%
! pip install torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.12/dist-packages (2.3.0+cpu)
# Requirement already satisfied: torchvision==0.18.0 in /usr/local/lib/python3.12/dist-packages (0.18.0+cpu)
# Requirement already satisfied: torchaudio==2.3.0 in /usr/local/lib/python3.12/dist-packages (2.3.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.3.0) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.18.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.18.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.3.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.3.0) (1.3.0)

# %%
! pip install pyannote.audio==3.4.0
# Out:
# Requirement already satisfied: pyannote.audio==3.4.0 in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (0.8.1)
# Requirement already satisfied: huggingface_hub>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (0.36.0)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.6.0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.3.0)
# Requirement already satisfied: pyannote.core<6.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (5.0.0)
# Requirement already satisfied: pyannote.database<6.0,>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (5.1.3)
# Requirement already satisfied: pyannote.metrics<4.0,>=3.2 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (3.2.1)
# Requirement already satisfied: pyannote.pipeline<4.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (3.0.1)
# Requirement already satisfied: pytorch_metric_learning>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (13.9.4)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (0.13.1)
# Requirement already satisfied: speechbrain>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (1.0.3)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.6.4)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.3.0+cpu)
# Requirement already satisfied: torch_audiomentations>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (0.12.0)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (2.3.0+cpu)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.4.0) (1.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.4.0) (2.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.4.0) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (1.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.4.0) (0.15.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.4.0) (2.6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==3.4.0) (4.9.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote.audio==3.4.0) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote.audio==3.4.0) (1.16.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (2.2.2)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (0.20.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.6.1)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (3.10.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.14.0)
# Requirement already satisfied: optuna>=3.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (4.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.4.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.4.0) (2.19.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->pyannote.audio==3.4.0) (2.0.0)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.4.0) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.4.0) (1.5.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain>=1.0.0->pyannote.audio==3.4.0) (0.2.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX>=2.6->pyannote.audio==3.4.0) (5.29.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.4.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.4.0) (3.1.6)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch_audiomentations>=0.11.0->pyannote.audio==3.4.0) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch_audiomentations>=0.11.0->pyannote.audio==3.4.0) (1.2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio==3.4.0) (2.23)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.1->pyannote.audio==3.4.0) (75.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio==3.4.0) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (2.9.0.post0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.1->pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (2.0.44)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.1->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch_audiomentations>=0.11.0->pyannote.audio==3.4.0) (1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.1->pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12.1->pyannote.database<6.0,>=5.0.1->pyannote.audio==3.4.0) (1.5.4)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio==3.4.0) (0.18.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->pyannote.audio==3.4.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.13.0->pyannote.audio==3.4.0) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.4.0) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==3.4.0) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio==3.4.0) (0.2.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline<4.0,>=3.0.1->pyannote.audio==3.4.0) (3.3.0)

# %%
# instantiate the pipeline
from pyannote.audio import Pipeline

pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token="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")
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _speechbrain_save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _speechbrain_load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _recover
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %% [markdown]
# FIRST AUDIO:

# %%
diarization1 = pipeline("./data/raw_audio/meeting01.wav")
# Out:
# /usr/local/lib/python3.12/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1807.)
#   std = sequences.std(dim=-1, correction=1)

# %%
segments = []
for turn, _, speaker in diarization1.itertracks(yield_label=True):
    segments.append({
        "start": round(turn.start, 3),
        "end": round(turn.end, 3),
        "speaker": speaker
    })

# %%
import json

output_path = "./data/diarizations/meeting01_diarization.json"

with open(output_path, "w") as f:
    json.dump({"segments": segments}, f, indent=2)

print("Diarization JSON saved to:", output_path)
# Out:
# Diarization JSON saved to: /content/drive/MyDrive/Colab Notebooks/NLP_final_project/data/diarization_output/meeting01_diarization.json

# %% [markdown]
# SECOND AUDIO:

# %%
diarization2 = pipeline("./data/raw_audio/meeting02.wav")

# %%
segments = []
for turn, _, speaker in diarization2.itertracks(yield_label=True):
    segments.append({
        "start": round(turn.start, 3),
        "end": round(turn.end, 3),
        "speaker": speaker
    })

# %%
import json

output_path = "./data/diarizations/meeting02_diarization.json"

with open(output_path, "w") as f:
    json.dump({"segments": segments}, f, indent=2)

print("Diarization JSON saved to:", output_path)
# Out:
# Diarization JSON saved to: /content/drive/MyDrive/Colab Notebooks/NLP_final_project/data/diarization_output/meeting02_diarization.json

# %% [markdown]
# THIRD AUDIO:

# %%
diarization3 = pipeline("./data/raw_audio/meeting03.wav")

# %%
segments = []
for turn, _, speaker in diarization3.itertracks(yield_label=True):
    segments.append({
        "start": round(turn.start, 3),
        "end": round(turn.end, 3),
        "speaker": speaker
    })

# %%
import json

output_path = "./data/diarizations/meeting03_diarization.json"

with open(output_path, "w") as f:
    json.dump({"segments": segments}, f, indent=2)

print("Diarization JSON saved to:", output_path)
# Out:
# Diarization JSON saved to: /content/drive/MyDrive/Colab Notebooks/NLP_final_project/data/diarization_output/meeting03_diarization.json

# %% [markdown]
# FOURTH AUDIO:

# %%
diarization4 = pipeline("./data/raw_audio/meeting03.wav")
# Out:
# /usr/local/lib/python3.12/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1807.)
#   std = sequences.std(dim=-1, correction=1)

# %%
segments = []
for turn, _, speaker in diarization4.itertracks(yield_label=True):
    segments.append({
        "start": round(turn.start, 3),
        "end": round(turn.end, 3),
        "speaker": speaker
    })

# %%
import json

output_path = "./data/diarized_json/meeting04_diarization.json"

with open(output_path, "w") as f:
    json.dump({"segments": segments}, f, indent=2)

print("Diarization JSON saved to:", output_path)
# Out:
# Diarization JSON saved to: /content/drive/MyDrive/Colab Notebooks/NLP_final_project/data/diarization_output/meeting04_diarization.json
